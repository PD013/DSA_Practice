# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def __init__(self, item, prev=None, next=None):
        # Initialize a node with an item and optional previous and next references
        self.item = item
        self.prev = prev
        self.next = next

class CDLL:
    def __init__(self):
        # Initialize an empty circular doubly linked list with a start node
        self.start = None

    def is_empty(self):
        # Check if the circular doubly linked list is empty
        return self.start is None

    def insert_at_start(self, data):
        # Insert a new node at the beginning of the circular doubly linked list
        n = Node(data)

        if not self.is_empty():
            # If the list is not empty, adjust pointers for the new node
            n.prev = self.start.prev
            n.next = self.start
            self.start.prev.next = n
            self.start.prev = n
            self.start = n
        else:
            # If the list is empty, set the start node to the new node
            self.start = n
            n.next = self.start
            n.prev = self.start
            # Making it circular


    def insert_at_last(self, data):
        # Insert a new node at the end of the circular doubly linked list
        n = Node(data)

        if not self.is_empty():
            # If the list is not empty, adjust pointers for the new node
            n.prev = self.start.prev
            n.next = self.start
            self.start.prev.next = n
            self.start.prev = n
        else:
            # If the list is empty, set the start node to the new node
            self.start = n
            n.next = self.start
            n.prev = self.start
        # Make it circular


    def search(self, data):
        # Search for a node with the given data in the circular doubly linked list

        if self.start is not None:
            temp = self.start.next  # Start checking from the 2nd Node

            if self.start.item == data:
                # Check the 1st Node because it was missed in the while loop
                return self.start

            while temp != self.start:
                # Iterate through the rest of the nodes until finding the data or reaching the starting point again
                if temp.item == data:
                    return temp
                temp = temp.next

            return None  # Return None if data is not found in the circular doubly linked list

        return None  # Return None if the list is already empty

    def insert_after(self,data,item):
        # Here we are inserting Item in the list which will come after the data
        if self.start is not None: # checks if list is empty
            temp = self.search(data)
            if temp is not None: #checks if data is present in the list or not
                n = Node(item,temp,temp.next)
                temp.next.prev = n
                temp.next = n

    def print_all(self):
      if not self.is_empty():
        i = 1
        temp = self.start
        while temp != self.start.prev:
            print(f"This is the {i}th Node with value {temp.item}")
            temp = temp.next
            i += 1
        print(f"This is the {i}th Node with value {temp.item}")
      else:
        print('Ohh shiit the list is empty')

    def delete_first(self):
        if not self.is_empty():
            if self.start.next == self.start:#Here it means there is only one Node
                self.start = None
                return
            self.start.next.prev = self.start.prev
            self.start.prev.next = self.start.next
            self.start = self.start.next

    def delete_last(self):
        if not self.is_empty():
            if self.start.prev == self.start:#Here it means there is only one Node
                self.start = None
                return
            self.start.prev.prev.next = self.start
            self.start.prev = self.start.prev.prev

    def delete_item(self,data):
        if not self.is_empty():
            # if self.start.next == self.start: #Checking if Only 1 node in the list
            #     if self.start.item == data: # Checking if in one node the data which needs to be deleted present
            #         self.start = None
            #         print("3")
            #         return
            #     else :
            #         print("The List is empty and not found required item to delete")
            #         return      #Noo need to explicitly delete the last Node its being done by below If statement

            if self.start.item == data:
                self.delete_first()
                return

            # if self.start.prev.item == data: #Noo need to explicitly delete the last Node its being done by below If statement
            #     self.delete_last()
            #     return

            temp = self.search(data)
            if temp is not None: #If there is more than 1 element in the node and could not search required item
                temp.prev.next = temp.next
                temp.next.prev = temp.prev
            else :
                print("Ohh in the Nodes the item which needs to be deleted is not present")
    def __iter__(self):
        if self.start==None:
            return CLLIterator(None)
        else:
            return CLLIterator(self.start) #Here we are giving last.next means 1st position


class CLLIterator:
    def __init__(self,start):
        self.current=start
        self.start=start
        self.count=0
    def __iter__(self):
        return self
    def __next__(self):
        if self.current==None: #IF list is empty
            raise StopIteration
        if self.current==self.start and self.count==1: #Here during 1st itteration it would satisfy
            raise StopIteration                        # 1st condition because current and start are both at same starting position
        else:                        # and not satisfy 2nd condition and it moves count = 1
            self.count=1             # Hence from next iteration it would satisfy 2nd condition and not 1st till it comes back after a loop
        data=self.current.item
        self.current=self.current.next  #Hence it can stop loop at the starting position only without repetations


        return data

cl1 = CDLL()
cl1.insert_at_start(5)
cl1.insert_at_start(4)
cl1.insert_at_start(3)
# cl1.insert_at_start(2)
# cl1.insert_at_start(1)
# cl1.insert_at_last(6)
# cl1.insert_after(3,3.5)
cl1.print_all()
cl1.delete_item(3)
cl1.print_all()

# for x in cl1:
#     print(x,end=' ')
# print()
# Out:
# This is the 0th Node with value 1
# This is the 1th Node with value 2
# This is the 2th Node with value 3
# This is the 3th Node with value 3.5
# This is the 4th Node with value 4
# This is the 5th Node with value 5
# This is the 6th Node with value 6
# Ohh in the Nodes the item which needs to be deleted is not present
# This is the 0th Node with value 1
# This is the 1th Node with value 2
# This is the 2th Node with value 3
# This is the 3th Node with value 3.5
# This is the 4th Node with value 4
# This is the 5th Node with value 5
# This is the 6th Node with value 6
# 1 2 3 3.5 4 5 6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def _init__(self,item,prev=None,next=None):
        self.item = item
        self.prev = prev
        self.next = next

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def _init__(self,item,prev=None,next=None):
        self.item = item
        self.prev = prev
        self.next = next
class CDLL:
    def __init__(self):
        self.start = None

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def _init__(self,item,prev=None,next=None):
        self.item = item
        self.prev = prev
        self.next = next
class CDLL:
    def __init__(self):
        self.start = None
    def is_empty(self):
        return self.last is None

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def _init__(self,item,prev=None,next=None):
        self.item = item
        self.prev = prev
        self.next = next
class CDLL:
    def __init__(self):
        self.start = None
    def is_empty(self):
        return self.last is None
    def insert_at_start(self,data):
        if not self.is_empty():
            n = Node(data,self.start.prev,self.start)
            self.start.prev.next = n
            self.start.prev = n
            self.start = n

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def _init__(self,item,prev=None,next=None):
        self.item = item
        self.prev = prev
        self.next = next
class CDLL:
    def __init__(self):
        self.start = None
    def is_empty(self):
        return self.last is None
    def insert_at_start(self,data):
        n = Node(data)
        if not self.is_empty():
            n.prev = self.start.prev
            n.next = self.start
            self.start.prev.next = n
            self.start.prev = n
            self.start = n
        self.start = n
        n.next = self.start
        n.prev = self.start
    def insert_at_last(self,data):
        n = Node(data)
        if not self.is_empty():
            n.prev = self.start.prev
            n.next = self.start
            self.start.prev.next = n
            self.start.prev = n
        self.start = n
        n.next = self.start
        n.prev = self.start

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def _init__(self,item,prev=None,next=None):
        self.item = item
        self.prev = prev
        self.next = next
class CDLL:
    def __init__(self):
        self.start = None
    def is_empty(self):
        return self.last is None
    def insert_at_start(self,data):
        n = Node(data)
        if not self.is_empty():
            n.prev = self.start.prev
            n.next = self.start
            self.start.prev.next = n
            self.start.prev = n
            self.start = n
        self.start = n
        n.next = self.start
        n.prev = self.start
    def insert_at_last(self,data):
        n = Node(data)
        if not self.is_empty():
            n.prev = self.start.prev
            n.next = self.start
            self.start.prev.next = n
            self.start.prev = n
        self.start = n
        n.next = self.start
        n.prev = self.start
    def search(self,data):
        if self.start is not None:
            temp =self.start.next #Starts checking from 2nd Node
            if self.start.item == data: #checks 1st Node beacause it was missed in the while loop
                return self.start
            while temp != self.start:
                if temp.item == data:
                    return temp
                temp = temp.next
            return None #This is if data is not found in the data
        return None #This is if The list is already empty

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def __init__(self, item, prev=None, next=None):
        # Initialize a node with an item and optional previous and next references
        self.item = item
        self.prev = prev
        self.next = next

class CDLL:
    def __init__(self):
        # Initialize an empty circular doubly linked list with a start node
        self.start = None

    def is_empty(self):
        # Check if the circular doubly linked list is empty
        return self.start is None

    def insert_at_start(self, data):
        # Insert a new node at the beginning of the circular doubly linked list
        n = Node(data)

        if not self.is_empty():
            # If the list is not empty, adjust pointers for the new node
            n.prev = self.start.prev
            n.next = self.start
            self.start.prev.next = n
            self.start.prev = n
            self.start = n
        else:
            # If the list is empty, set the start node to the new node
            self.start = n
            n.next = self.start
            n.prev = self.start
            # Making it circular


    def insert_at_last(self, data):
        # Insert a new node at the end of the circular doubly linked list
        n = Node(data)

        if not self.is_empty():
            # If the list is not empty, adjust pointers for the new node
            n.prev = self.start.prev
            n.next = self.start
            self.start.prev.next = n
            self.start.prev = n
        else:
            # If the list is empty, set the start node to the new node
            self.start = n
            n.next = self.start
            n.prev = self.start
        # Make it circular


    def search(self, data):
        # Search for a node with the given data in the circular doubly linked list

        if self.start is not None:
            temp = self.start.next  # Start checking from the 2nd Node

            if self.start.item == data:
                # Check the 1st Node because it was missed in the while loop
                return self.start

            while temp != self.start:
                # Iterate through the rest of the nodes until finding the data or reaching the starting point again
                if temp.item == data:
                    return temp
                temp = temp.next

            return None  # Return None if data is not found in the circular doubly linked list

        return None  # Return None if the list is already empty

    def insert_after(self,data,item):
        # Here we are inserting Item in the list which will come after the data
        if self.start is not None: # checks if list is empty
            temp = self.search(data)
            if temp is not None: #checks if data is present in the list or not
                n = Node(item,temp,temp.next)
                temp.next.prev = n
                temp.next = n

cl1 = CDLL()
cl1.insert_at_start(5)
cl1.insert_at_start(4)
cl1.insert_at_start(3)
cl1.insert_at_start(2)
cl1.insert_at_start(1)
cl1.insert_at_last(6)
cl1.insert_after(3,3.5)
cl1.print_all()
# Out:
# This is the 1th Node with value 1
# This is the 2th Node with value 2
# This is the 3th Node with value 3
# This is the 4th Node with value 3.5
# This is the 5th Node with value 4
# This is the 6th Node with value 5
# This is the 7th Node with value 6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def __init__(self, item, prev=None, next=None):
        # Initialize a node with an item and optional previous and next references
        self.item = item
        self.prev = prev
        self.next = next

class CDLL:
    def __init__(self):
        # Initialize an empty circular doubly linked list with a start node
        self.start = None

    def is_empty(self):
        # Check if the circular doubly linked list is empty
        return self.start is None

    def insert_at_start(self, data):
        # Insert a new node at the beginning of the circular doubly linked list
        n = Node(data)

        if not self.is_empty():
            # If the list is not empty, adjust pointers for the new node
            n.prev = self.start.prev
            n.next = self.start
            self.start.prev.next = n
            self.start.prev = n
            self.start = n
        else:
            # If the list is empty, set the start node to the new node
            self.start = n
            n.next = self.start
            n.prev = self.start
            # Making it circular


    def insert_at_last(self, data):
        # Insert a new node at the end of the circular doubly linked list
        n = Node(data)

        if not self.is_empty():
            # If the list is not empty, adjust pointers for the new node
            n.prev = self.start.prev
            n.next = self.start
            self.start.prev.next = n
            self.start.prev = n
        else:
            # If the list is empty, set the start node to the new node
            self.start = n
            n.next = self.start
            n.prev = self.start
        # Make it circular


    def search(self, data):
        # Search for a node with the given data in the circular doubly linked list

        if self.start is not None:
            temp = self.start.next  # Start checking from the 2nd Node

            if self.start.item == data:
                # Check the 1st Node because it was missed in the while loop
                return self.start

            while temp != self.start:
                # Iterate through the rest of the nodes until finding the data or reaching the starting point again
                if temp.item == data:
                    return temp
                temp = temp.next

            return None  # Return None if data is not found in the circular doubly linked list

        return None  # Return None if the list is already empty

    def insert_after(self,data,item):
        # Here we are inserting Item in the list which will come after the data
        if self.start is not None: # checks if list is empty
            temp = self.search(data)
            if temp is not None: #checks if data is present in the list or not
                n = Node(item,temp,temp.next)
                temp.next.prev = n
                temp.next = n

    def print_all(self):
      if not self.is_empty():
        i = 1
        temp = self.start
        while temp != self.start.prev:
            print(f"This is the {i}th Node with value {temp.item}")
            temp = temp.next
            i += 1
        print(f"This is the {i}th Node with value {temp.item}")


cl1 = CDLL()
cl1.insert_at_start(5)
cl1.insert_at_start(4)
cl1.insert_at_start(3)
cl1.insert_at_start(2)
cl1.insert_at_start(1)
cl1.insert_at_last(6)
cl1.insert_after(3,3.5)
cl1.print_all()
# Out:
# This is the 1th Node with value 1
# This is the 2th Node with value 2
# This is the 3th Node with value 3
# This is the 4th Node with value 3.5
# This is the 5th Node with value 4
# This is the 6th Node with value 5
# This is the 7th Node with value 6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def __init__(self, item, prev=None, next=None):
        # Initialize a node with an item and optional previous and next references
        self.item = item
        self.prev = prev
        self.next = next

class CDLL:
    def __init__(self):
        # Initialize an empty circular doubly linked list with a start node
        self.start = None

    def is_empty(self):
        # Check if the circular doubly linked list is empty
        return self.start is None

    def insert_at_start(self, data):
        # Insert a new node at the beginning of the circular doubly linked list
        n = Node(data)

        if not self.is_empty():
            # If the list is not empty, adjust pointers for the new node
            n.prev = self.start.prev
            n.next = self.start
            self.start.prev.next = n
            self.start.prev = n
            self.start = n
        else:
            # If the list is empty, set the start node to the new node
            self.start = n
            n.next = self.start
            n.prev = self.start
            # Making it circular


    def insert_at_last(self, data):
        # Insert a new node at the end of the circular doubly linked list
        n = Node(data)

        if not self.is_empty():
            # If the list is not empty, adjust pointers for the new node
            n.prev = self.start.prev
            n.next = self.start
            self.start.prev.next = n
            self.start.prev = n
        else:
            # If the list is empty, set the start node to the new node
            self.start = n
            n.next = self.start
            n.prev = self.start
        # Make it circular


    def search(self, data):
        # Search for a node with the given data in the circular doubly linked list

        if self.start is not None:
            temp = self.start.next  # Start checking from the 2nd Node

            if self.start.item == data:
                # Check the 1st Node because it was missed in the while loop
                return self.start

            while temp != self.start:
                # Iterate through the rest of the nodes until finding the data or reaching the starting point again
                if temp.item == data:
                    return temp
                temp = temp.next

            return None  # Return None if data is not found in the circular doubly linked list

        return None  # Return None if the list is already empty

    def insert_after(self,data,item):
        # Here we are inserting Item in the list which will come after the data
        if self.start is not None: # checks if list is empty
            temp = self.search(data)
            if temp is not None: #checks if data is present in the list or not
                n = Node(item,temp,temp.next)
                temp.next.prev = n
                temp.next = n

    def print_all(self):
      if not self.is_empty():
        i = 1
        temp = self.start
        while temp != self.start.prev:
            print(f"This is the {i}th Node with value {temp.item}")
            temp = temp.next
            i += 1
        print(f"This is the {i}th Node with value {temp.item}")
      else:
        print('Ohh shiit the list is empty')

    def delete_first(self):
        if not self.is_empty():
            if self.start.next == self.start:#Here it means there is only one Node
                self.start = None
                return
            self.start.next.prev = self.start.prev
            self.start.prev.next = self.start.next
            self.start = self.start.next



cl1 = CDLL()
cl1.insert_at_start(5)
# cl1.insert_at_start(4)
# cl1.insert_at_start(3)
# cl1.insert_at_start(2)
# cl1.insert_at_start(1)
# cl1.insert_at_last(6)
# cl1.insert_after(3,3.5)
cl1.print_all()
cl1.delete_first()
cl1.print_all()
# Out:
# This is the 1th Node with value 5
# Ohh shiit the list is empty

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def __init__(self, item, prev=None, next=None):
        # Initialize a node with an item and optional previous and next references
        self.item = item
        self.prev = prev
        self.next = next

class CDLL:
    def __init__(self):
        # Initialize an empty circular doubly linked list with a start node
        self.start = None

    def is_empty(self):
        # Check if the circular doubly linked list is empty
        return self.start is None

    def insert_at_start(self, data):
        # Insert a new node at the beginning of the circular doubly linked list
        n = Node(data)

        if not self.is_empty():
            # If the list is not empty, adjust pointers for the new node
            n.prev = self.start.prev
            n.next = self.start
            self.start.prev.next = n
            self.start.prev = n
            self.start = n
        else:
            # If the list is empty, set the start node to the new node
            self.start = n
            n.next = self.start
            n.prev = self.start
            # Making it circular


    def insert_at_last(self, data):
        # Insert a new node at the end of the circular doubly linked list
        n = Node(data)

        if not self.is_empty():
            # If the list is not empty, adjust pointers for the new node
            n.prev = self.start.prev
            n.next = self.start
            self.start.prev.next = n
            self.start.prev = n
        else:
            # If the list is empty, set the start node to the new node
            self.start = n
            n.next = self.start
            n.prev = self.start
        # Make it circular


    def search(self, data):
        # Search for a node with the given data in the circular doubly linked list

        if self.start is not None:
            temp = self.start.next  # Start checking from the 2nd Node

            if self.start.item == data:
                # Check the 1st Node because it was missed in the while loop
                return self.start

            while temp != self.start:
                # Iterate through the rest of the nodes until finding the data or reaching the starting point again
                if temp.item == data:
                    return temp
                temp = temp.next

            return None  # Return None if data is not found in the circular doubly linked list

        return None  # Return None if the list is already empty

    def insert_after(self,data,item):
        # Here we are inserting Item in the list which will come after the data
        if self.start is not None: # checks if list is empty
            temp = self.search(data)
            if temp is not None: #checks if data is present in the list or not
                n = Node(item,temp,temp.next)
                temp.next.prev = n
                temp.next = n

    def print_all(self):
      if not self.is_empty():
        i = 1
        temp = self.start
        while temp != self.start.prev:
            print(f"This is the {i}th Node with value {temp.item}")
            temp = temp.next
            i += 1
        print(f"This is the {i}th Node with value {temp.item}")
      else:
        print('Ohh shiit the list is empty')

    def delete_first(self):
        if not self.is_empty():
            if self.start.next == self.start:#Here it means there is only one Node
                self.start = None
                return
            self.start.next.prev = self.start.prev
            self.start.prev.next = self.start.next
            self.start = self.start.next

    def delete_last(self):
        if not self.is_empty():
            if self.start.prev == self.start:#Here it means there is only one Node
                self.start = None
                return
            self.start.prev.prev.next = self.start
            self.start.prev = self.start.prev.prev


cl1 = CDLL()
cl1.insert_at_start(5)
cl1.insert_at_start(4)
cl1.insert_at_start(3)
cl1.insert_at_start(2)
# cl1.insert_at_start(1)
# cl1.insert_at_last(6)
# cl1.insert_after(3,3.5)
cl1.print_all()
cl1.delete_last()
cl1.print_all()
# Out:
# This is the 1th Node with value 2
# This is the 2th Node with value 3
# This is the 3th Node with value 4
# This is the 4th Node with value 5
# This is the 1th Node with value 2
# This is the 2th Node with value 3
# This is the 3th Node with value 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def __init__(self, item, prev=None, next=None):
        # Initialize a node with an item and optional previous and next references
        self.item = item
        self.prev = prev
        self.next = next

class CDLL:
    def __init__(self):
        # Initialize an empty circular doubly linked list with a start node
        self.start = None

    def is_empty(self):
        # Check if the circular doubly linked list is empty
        return self.start is None

    def insert_at_start(self, data):
        # Insert a new node at the beginning of the circular doubly linked list
        n = Node(data)

        if not self.is_empty():
            # If the list is not empty, adjust pointers for the new node
            n.prev = self.start.prev
            n.next = self.start
            self.start.prev.next = n
            self.start.prev = n
            self.start = n
        else:
            # If the list is empty, set the start node to the new node
            self.start = n
            n.next = self.start
            n.prev = self.start
            # Making it circular


    def insert_at_last(self, data):
        # Insert a new node at the end of the circular doubly linked list
        n = Node(data)

        if not self.is_empty():
            # If the list is not empty, adjust pointers for the new node
            n.prev = self.start.prev
            n.next = self.start
            self.start.prev.next = n
            self.start.prev = n
        else:
            # If the list is empty, set the start node to the new node
            self.start = n
            n.next = self.start
            n.prev = self.start
        # Make it circular


    def search(self, data):
        # Search for a node with the given data in the circular doubly linked list

        if self.start is not None:
            temp = self.start.next  # Start checking from the 2nd Node

            if self.start.item == data:
                # Check the 1st Node because it was missed in the while loop
                return self.start

            while temp != self.start:
                # Iterate through the rest of the nodes until finding the data or reaching the starting point again
                if temp.item == data:
                    return temp
                temp = temp.next

            return None  # Return None if data is not found in the circular doubly linked list

        return None  # Return None if the list is already empty

    def insert_after(self,data,item):
        # Here we are inserting Item in the list which will come after the data
        if self.start is not None: # checks if list is empty
            temp = self.search(data)
            if temp is not None: #checks if data is present in the list or not
                n = Node(item,temp,temp.next)
                temp.next.prev = n
                temp.next = n

    def print_all(self):
      if not self.is_empty():
        i = 1
        temp = self.start
        while temp != self.start.prev:
            print(f"This is the {i}th Node with value {temp.item}")
            temp = temp.next
            i += 1
        print(f"This is the {i}th Node with value {temp.item}")
      else:
        print('Ohh shiit the list is empty')

    def delete_first(self):
        if not self.is_empty():
            if self.start.next == self.start:#Here it means there is only one Node
                self.start = None
                return
            self.start.next.prev = self.start.prev
            self.start.prev.next = self.start.next
            self.start = self.start.next

    def delete_last(self):
        if not self.is_empty():
            if self.start.prev == self.start:#Here it means there is only one Node
                self.start = None
                return
            self.start.prev.prev.next = self.start
            self.start.prev = self.start.prev.prev

    def delete_item(self,data):
        if not self.is_empty():
            if self.start.next == self.start: #Checking if Only 1 node in the list
                if self.start.item == data: # Checking if in one node the data which needs to be deleted present
                    self.start = None
                    return
                else :
                    print("The List is empty and not found required item to delete")
                    return
            if self.start.item == data:
                self.delete_first()
            if self.start.prev.item == data:
                self.delete_last()
            temp = self.search(data)
            if temp is not None: #If there is more than 1 element in the node and could not search required item
                temp.prev.next = temp.next
                temp.next.prev = temp.prev
            else :
                print("Ohh in the Nodes the item which needs to be deleted is not present")



cl1 = CDLL()
cl1.insert_at_start(5)
cl1.insert_at_start(4)
cl1.insert_at_start(3)
cl1.insert_at_start(2)
# cl1.insert_at_start(1)
# cl1.insert_at_last(6)
# cl1.insert_after(3,3.5)
cl1.print_all()
cl1.delete_item(6)
cl1.print_all()
# Out:
# This is the 1th Node with value 2
# This is the 2th Node with value 3
# This is the 3th Node with value 4
# This is the 4th Node with value 5
# Ohh in the Nodes the item which needs to be deleted is not present
# This is the 1th Node with value 2
# This is the 2th Node with value 3
# This is the 3th Node with value 4
# This is the 4th Node with value 5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def __init__(self, item, prev=None, next=None):
        # Initialize a node with an item and optional previous and next references
        self.item = item
        self.prev = prev
        self.next = next

class CDLL:
    def __init__(self):
        # Initialize an empty circular doubly linked list with a start node
        self.start = None

    def is_empty(self):
        # Check if the circular doubly linked list is empty
        return self.start is None

    def insert_at_start(self, data):
        # Insert a new node at the beginning of the circular doubly linked list
        n = Node(data)

        if not self.is_empty():
            # If the list is not empty, adjust pointers for the new node
            n.prev = self.start.prev
            n.next = self.start
            self.start.prev.next = n
            self.start.prev = n
            self.start = n
        else:
            # If the list is empty, set the start node to the new node
            self.start = n
            n.next = self.start
            n.prev = self.start
            # Making it circular


    def insert_at_last(self, data):
        # Insert a new node at the end of the circular doubly linked list
        n = Node(data)

        if not self.is_empty():
            # If the list is not empty, adjust pointers for the new node
            n.prev = self.start.prev
            n.next = self.start
            self.start.prev.next = n
            self.start.prev = n
        else:
            # If the list is empty, set the start node to the new node
            self.start = n
            n.next = self.start
            n.prev = self.start
        # Make it circular


    def search(self, data):
        # Search for a node with the given data in the circular doubly linked list

        if self.start is not None:
            temp = self.start.next  # Start checking from the 2nd Node

            if self.start.item == data:
                # Check the 1st Node because it was missed in the while loop
                return self.start

            while temp != self.start:
                # Iterate through the rest of the nodes until finding the data or reaching the starting point again
                if temp.item == data:
                    return temp
                temp = temp.next

            return None  # Return None if data is not found in the circular doubly linked list

        return None  # Return None if the list is already empty

    def insert_after(self,data,item):
        # Here we are inserting Item in the list which will come after the data
        if self.start is not None: # checks if list is empty
            temp = self.search(data)
            if temp is not None: #checks if data is present in the list or not
                n = Node(item,temp,temp.next)
                temp.next.prev = n
                temp.next = n

    def print_all(self):
      if not self.is_empty():
        i = 1
        temp = self.start
        while temp != self.start.prev:
            print(f"This is the {i}th Node with value {temp.item}")
            temp = temp.next
            i += 1
        print(f"This is the {i}th Node with value {temp.item}")
      else:
        print('Ohh shiit the list is empty')

    def delete_first(self):
        if not self.is_empty():
            if self.start.next == self.start:#Here it means there is only one Node
                self.start = None
                return
            self.start.next.prev = self.start.prev
            self.start.prev.next = self.start.next
            self.start = self.start.next

    def delete_last(self):
        if not self.is_empty():
            if self.start.prev == self.start:#Here it means there is only one Node
                self.start = None
                return
            self.start.prev.prev.next = self.start
            self.start.prev = self.start.prev.prev

    def delete_item(self,data):
        if not self.is_empty():
            # if self.start.next == self.start: #Checking if Only 1 node in the list
            #     if self.start.item == data: # Checking if in one node the data which needs to be deleted present
            #         self.start = None
            #         print("3")
            #         return
            #     else :
            #         print("The List is empty and not found required item to delete")
            #         return      #Noo need to explicitly delete the last Node its being done by below If statement

            if self.start.item == data:
                self.delete_first()
                return

            # if self.start.prev.item == data: #Noo need to explicitly delete the last Node its being done by below If statement
            #     self.delete_last()
            #     return

            temp = self.search(data)
            if temp is not None: #If there is more than 1 element in the node and could not search required item
                temp.prev.next = temp.next
                temp.next.prev = temp.prev
            else :
                print("Ohh in the Nodes the item which needs to be deleted is not present")
    def __iter__(self):
        if self.start==None:
            return CLLIterator(None)
        else:
            return CLLIterator(self.start) #Here we are giving last.next means 1st position


class CLLIterator:
    def __init__(self,start):
        self.current=start
        self.start=start
        self.count=0
    def __iter__(self):
        return self
    def __next__(self):
        if self.current==None: #IF list is empty
            raise StopIteration
        if self.current==self.start and self.count==1: #Here during 1st itteration it would satisfy
            raise StopIteration                        # 1st condition because current and start are both at same starting position
        else:                        # and not satisfy 2nd condition and it moves count = 1
            self.count=1             # Hence from next iteration it would satisfy 2nd condition and not 1st till it comes back after a loop
        data=self.current.item
        self.current=self.current.next  #Hence it can stop loop at the starting position only without repetations


        return data

cl1 = CDLL()
cl1.insert_at_start(5)
cl1.insert_at_start(4)
cl1.insert_at_start(3)
# cl1.insert_at_start(2)
# cl1.insert_at_start(1)
# cl1.insert_at_last(6)
# cl1.insert_after(3,3.5)
cl1.print_all()
cl1.delete_item(3)
cl1.print_all()

# for x in cl1:
#     print(x,end=' ')
# print()
# Out:
# This is the 1th Node with value 3
# This is the 2th Node with value 4
# This is the 3th Node with value 5
# This is the 1th Node with value 4
# This is the 2th Node with value 5
