# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# SIRS COde
class PriorityQueue:
    def __init__(self):
        self.items=[]
    def push(self,data,priority):
        index=0
        while index<len(self.items) and self.items[index][1]<=priority:
            index+=1
        self.items.insert(index,(data,priority))
    def is_empty(self):
        return len(self.items)==0
    def pop(self):
        if self.is_empty():
            raise IndexError("Priority Queue is Empty")
        return self.items.pop(0)[0]
    def size(self):
        return len(self.items)
p=PriorityQueue()
p.push("Amit",4)
p.push("Arjun",7)
p.push("Ashima",2)
p.push("Agrah",5)
p.push("Anant",8)
p.push("Ambika",1)

while not p.is_empty():
    print(p.pop())
# Out:
# Ambika
# Ashima
# Amit
# Agrah
# Arjun
# Anant

# %%
# MYY COODE
# So what I have implemented is not actual priority queue because I have just added position number with push where
# where if position number mentioned then it will be placed there nothing special so its not proper
class PriorityQueue:
    def __init__(self):
        self.mylist = []
        self.priorityNum = None

    def is_empty(self):
        return not self.mylist

    def push(self,data,number):
        if not self.is_empty():
            self.mylist.insert(number-1,data)
        else:
            self.mylist.append(data)

    def pop(self):
        if not self.is_empty():
            self.mylist.pop(0)
        else:
            raise IndexError("The list is empty")

    def size(self):
        if not self.is_empty():
            return len(self.mylist)
        else:
            raise IndexError("The list is empty")

    def show(self):
        return self.mylist

pq = PriorityQueue()

    # Test Case 1: Push elements with different priorities
print("Test Case 1:")
pq.push(10, 2)
print("Priority Queue:", pq.show())

pq.push(11, 2)
print("Priority Queue:", pq.show())

pq.push(12, 3)
print("Priority Queue:", pq.show())

pq.push(11.5, 3)
print("Priority Queue:", pq.show())

    # Test Case 2: Pop an element
print("\nTest Case 2:")
pq.pop()
print("Priority Queue after pop:", pq.show())

    # Test Case 3: Size of the priority queue
print("\nTest Case 3:")
size = pq.size()
print("Size of Priority Queue:", size)

    # Test Case 4: Push an element with a different priority
print("\nTest Case 4:")
pq.push(9, 8)
print("Priority Queue after push:", pq.show())

print("\nTest Case 5:")
pq.push(10, 7)
print("Priority Queue after push:", pq.show())
# Out:
# Test Case 1:
# Priority Queue: [10]
# Priority Queue: [10, 11]
# Priority Queue: [10, 11, 12]
# Priority Queue: [10, 11, 11.5, 12]
#
# Test Case 2:
# Priority Queue after pop: [11, 11.5, 12]
#
# Test Case 3:
# Size of Priority Queue: 3
#
# Test Case 4:
# Priority Queue after push: [11, 11.5, 12, 9]
#
# Test Case 5:
# Priority Queue after push: [11, 11.5, 12, 9, 10]

# %% [markdown]
# ![image.png](data:image/png;base64,...)
