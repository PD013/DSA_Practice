# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Sir's Code
def insertion_sort(list1):
    for i in range(1 , len(list1)):
        temp = list1[i]
        j = i-1
        while j >=0 and temp<list1[j]:
            list1[j+1] = list1[j]
            j -=1
        list1[j+1] = temp

list1 = [3,4,2,1,5,9,7,6,8]
print(insertion_sort(list1))
print(list1)
# Out:
# None
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# This is Insertion Sort MY Logic not able to code it correctly
class sorting:
    def __init__(self):
        pass
    def insertion(self,lst):
        n = len(lst)
        for i in range(n):
            if lst[i] > lst[i+1]:
               temp = lst[i+1]
               for j in reversed(lst[:i]):
                   if j > temp:

s1 = sorting()
list1 = [3,4,2,1,5,9,7,6,8]
print(s1.insertion(list1))
# Out:
# [4, 5, 9, 7, 6, 8, 3]

# %% [markdown]
# ![image.png](data:image/png;base64,...)
