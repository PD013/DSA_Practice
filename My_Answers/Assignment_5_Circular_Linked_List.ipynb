# %% [markdown]
# ## **Sorry to SAY But Ur Whole Coode is Wrong And Needs to be rewritten Also Other Assignments(`DONE`) also because you have not used features like code reusability also you are making it lenghty when it can be completed in short **

# %%
class Node:
    def __init__(self,item,next = None):
        self.item = item
        self.next = next
class CLL:
    def __init__(self,last=None):
        self.last = last
    def is_empty(self):
        return self.last is None
    def insert_at_start(self,data):
        n=Node(data)
        if self.is_empty():
            n.next=n
            self.last=n
        else:
            n.next=self.last.next
            self.last.next=n
    def insert_at_last(self,data):
        n = Node(data)
        if self.is_empty():
            n.next = n #Making loop on itself
            self.last = n
        else:
            n.next = self.last.next
            self.last.next = n
            self.last = n
    def search(self,data):
        if self.is_empty():
            return None
        temp=self.last.next
        while temp!=self.last:
            if temp.item==data:
                return temp
            temp=temp.next
        if temp.item==data: # This is to check for the last noode because it was missed in the above itterations
            return temp
        return None
    def insert_after(self,temp,data):
        if temp is not None:
            n=Node(data,temp.next)
            temp.next=n
            if temp==self.last: # Check if its last node then change self.last to new_node
                self.last=n
    def print_list(self):
        if not self.is_empty():
            temp=self.last.next # Take the temp to 1st position
            while temp!=self.last: #Iterate and print till 2nd last position
                print(temp.item,end=' ')
                temp=temp.next
            print(temp.item) #its when there is only one node or to print the last node

    def delete_first(self):
      if self.last is not None:
          if self.last.next != self.last:
              self.last.next = self.last.next.next
              return
          self.last = None

    def delete_last(self):
        if self.last is not None:
            if self.last.next == self.last:
                self.last=None
            else:
                temp = self.last.next
                while temp.next != self.last:
                      temp = temp.next
            temp.next = self.last.next
            self.last = temp

    def delete_item(self,data):
        if not self.is_empty():
            if self.last.next==self.last:
                if self.last.item==data:
                    self.last=None
            else:
                if self.last.next.item==data:
                    self.delete_first()
                else:
                    temp=self.last.next

                    while temp!=self.last:
                        if temp.next==self.last:
                            if self.last.item==data:
                                self.delete_last()
                            break
                        if temp.next.item==data:
                            temp.next=temp.next.next
                            break
                        temp=temp.next

    def __iter__(self):
        if self.last==None:
            return CLLIterator(None)
        else:
            return CLLIterator(self.last.next) #Here we are giving last.next means 1st position


class CLLIterator:
    def __init__(self,start):
        self.current=start
        self.start=start
        self.count=0
    def __iter__(self):
        return self
    def __next__(self):
        if self.current==None: #IF list is empty
            raise StopIteration
        if self.current==self.start and self.count==1: #Here during 1st itteration it would satisfy
            raise StopIteration                        # 1st condition because current and start are both at same starting position
        else:                        # and not satisfy 2nd condition and it moves count = 1
            self.count=1             # Hence from next iteration it would satisfy 2nd condition and not 1st till it comes back after a loop
        self.current=self.current.next  #Hence it can stop loop at the starting position only without repetations
        data=self.current.item

        return data

cll= CLL()
cll.insert_at_start(10)
cll.insert_at_start(20)
cll.insert_at_last(30)
cll.insert_at_last(40)
cll.insert_after(cll.search(10),50)
cll.print_list()
# 20 10 50 30 40
for x in cll:
    print(x,end=' ')
print()
# cll.print_list()
# Out:
# 20 10 50 30 40
# 10 50 30 40 20

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

class CLL:
    def __init__(self):
        self.last = None

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

class CLL:
    def __init__(self):
        self.last = None

    def is_empty(self):
        return self.last is None

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

class CLL:
    def __init__(self):
        self.last = None

    def is_empty(self):
        return self.last is None

    def insert_at_start(self,data):
        n = Node(data)
        if self.last is not None:
            n.next = self.last.next
            self.last.next = n
        else:
           self.last = n
           self.last.next = n

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

class CLL:
    def __init__(self):
        self.last = None

    def is_empty(self):
        return self.last is None

    def insert_at_start(self,data):
        new_node = Node(data)
        if self.last is not None:
            new_node.next = self.last.next
            self.last.next = new_node
        else:
           self.last = new_node
           new_node.next = new_node

    def insert_at_last(self,data):
        new_node = Node(data)
        if self.last is not None:
            new_node.next = self.last.next
            self.last.next = new_node
            self.last = new_node
        else:
           self.last = new_node
           new_node.next = new_node

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

class CLL:
    def __init__(self):
        self.last = None

    def is_empty(self):
        return self.last is None

    def insert_at_start(self,data):
        new_node = Node(data)
        if self.last is not None:
            new_node.next = self.last.next
            self.last.next = new_node
        else:
           self.last = new_node
           new_node.next = new_node

    def insert_at_last(self,data):
        new_node = Node(data)
        if self.last is not None:
            new_node.next = self.last.next
            self.last.next = new_node
            self.last = new_node
        else:
           self.last = new_node
           new_node.next = new_node

    def search(self,data):
        if self.last is None:
            print('Sorry, the list is empty')
            return

        temp = self.last
         #Here if the data is in the last node
        if temp.data == data:
            print('The data is in the Last Node')
            return
        i = 1

        while temp.next.data != data:
            if temp.next == self.last:
                print(f"Data '{data}' not found in the linked list.")
                return
            temp = temp.next
            i += 1
        print(f"The data '{data}' is in the {i}th Node! Congrats")

cll = CLL()
# cll.insert_at_start(1)
# cll.insert_at_last(2)
# cll.insert_at_last(3)
# cll.insert_at_last(4)
# cll.insert_at_last(5)
# cll.insert_at_last(6)
cll.insert_at_start(0.5)
cll.search(0.5)
# Out:
# The data is in the Last Node

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-cd1e90a1a19b> in <cell line: 89>()
#      87 cll.insert_at_last(6)
#      88 cll.insert_at_start(0.5)
# ---> 89 cll.insert_after(7,6)
#      90 cll.search(7)
#      91
#
# <ipython-input-29-cd1e90a1a19b> in insert_after(self, temp, data)
#      75         if temp is not None:
#      76             n=Node(data)
# ---> 77             n.next = temp.next
#      78             temp.next=n
#      79             if temp==self.last:
#
# AttributeError: 'int' object has no attribute 'next'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)**bold text**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
