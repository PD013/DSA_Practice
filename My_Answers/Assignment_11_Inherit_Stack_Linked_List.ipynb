# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# SIRS Code
from Assign3_ANSWER_SIR import *
class Stack(SLL):
    def __init__(self):
# In other language eg java or c++ when constructor of child class is called it automatically calls constructor oof parent class
# as here in py constructor is init method also it does not call the parent constructor automatic so we have to call it using super method here
        super().__init__()  # Calling parent init variable too create the start variable
        self.item_count=0
    def is_empty(self):
        return super().is_empty()
    def push(self,data):
        self.insert_at_start(data)
        self.item_count+=1
    def pop(self):
        if not self.is_empty():
            self.delete_first()
            self.item_count-=1
        else:
            raise IndexError("Stack Underflow")
    def peek(self):
        if not self.is_empty():
            return self.start.item
        else:
            raise IndexError("Stack Underflow")
    def size(self):
        return self.item_count
s1=Stack()
s1.push(10)
s1.push(20)
s1.push(30)
print("Top element on the stack: ",s1.peek())
s1.pop()
print("Top element on the stack: ",s1.peek())
# Out:
# Top element on the stack:  30
# Top element on the stack:  20

# %%
# MY Code working one # Modified BY sirs code
# MY Final Working SOlution
class Stack(SLL):

    def __init__(self):
        super().__init__()
        self.counter = 0

    def is_empty(self):
        return super().is_empty()

    def push(self,data):
        self.counter += 1
        self.insert_at_start(data)
    def pop(self):
        if not self.is_empty():
            self.counter -= 1
            return self.delete_first()
        else:
            raise IndexError("Stack Underflow")
    def peek(self):
        if not self.is_empty():
            return self.start.item

    def size(self):
        return self.counter

s=Stack()
s.push(10)
s.push(20)
s.push(30)
print("Top element is",s.peek())
print("Size of element is",s.size())
s.pop()
print("Top element is",s.peek())
print("Size of element is",s.size())
s.pop()
print("Top element is",s.peek())
print("Size of element is",s.size())
# Out:
# Top element is 30
# Size of element is 3
# Top element is 20
# Size of element is 2
# Top element is 10
# Size of element is 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Here !wget and %load are magic commands in Jupyter notebooks. (Cannot work at other places)
# Use !wget to download the script from GitHub (Here I imported Sirs Code and Not Mine (Mine in ipynb))
# !wget https://github.com/PD013/DSA_Practice/raw/main/MySirG_Answers/Assign3_ANSWER_SIR.py

# Use %load to load the content into the cell
# %load Assign3_ANSWER_SIR.py

# here we are downloading and creating a file in same folder to use in this script

from Assign3_ANSWER_SIR import *
# Out:
# --2023-12-21 12:57:44--  https://github.com/PD013/DSA_Practice/raw/main/MySirG_Answers/Assign3_ANSWER_SIR.py
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/PD013/DSA_Practice/main/MySirG_Answers/Assign3_ANSWER_SIR.py [following]
# --2023-12-21 12:57:45--  https://raw.githubusercontent.com/PD013/DSA_Practice/main/MySirG_Answers/Assign3_ANSWER_SIR.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2728 (2.7K) [text/plain]
# Saving to: ‘Assign3_ANSWER_SIR.py’
#
# Assign3_ANSWER_SIR. 100%[===================>]   2.66K  --.-KB/s    in 0s
#
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Stack(SLL):
  pass
# Out:
#   File "<ipython-input-3-097c3d698682>", line 3
#     def is_empty():
#                            ^
# SyntaxError: incomplete input

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Stack(SLL):
    def is_empty():
        return super.is_empty()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Stack(SLL):
    def is_empty():
        return super.is_empty()

    def push(self,data):
        if not is_empty():
            return insert_at_start(data)
        else:
            raise IndexError("It Empty")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Stack(SLL):
    def is_empty():
        return super.is_empty()

    def push(self,data):
        if not is_empty():
            return insert_at_start(data)
        else:
            raise IndexError("It Empty")
    def pop(self):
        if not is_empty():
            delete_first()
            return
        else:
            raise IndexError("It Empty")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Stack(SLL):
    def is_empty():
        return super.is_empty()

    def push(self,data):
        if not is_empty():
            return insert_at_start(data)
        else:
            raise IndexError("It Empty")
    def pop(self):
        if not is_empty():
            delete_first()
            return
        else:
            raise IndexError("It Empty")
    def peek(self):
        if not is_empty():
            return self.start.item

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# MY Final Working SOlution
class Stack(SLL):

    def __init__(self):
        self.start = SLL()
        self.counter = 0

    def is_empty(self):
        return super().is_empty()

    def push(self,data):
        if not self.is_empty():
            self.counter += 1
            return self.insert_at_start(data)
        else:
            raise IndexError("It Empty")
    def pop(self):
        if not self.is_empty():
            self.counter -= 1
            super().delete_first()
            return
        else:
            raise IndexError("It Empty")
    def peek(self):
        if not self.is_empty():
            return self.start.item

    def size(self):
        return self.counter

s=Stack()
s.push(10)
s.push(20)
s.push(30)
print("Top element is",s.peek())
print("Size of element is",s.size())
s.pop()
print("Top element is",s.peek())
print("Size of element is",s.size())
s.pop()
print("Top element is",s.peek())
print("Size of element is",s.size())
# Out:
# Top element is 30
# Size of element is 3
# Top element is 20
# Size of element is 2
# Top element is 10
# Size of element is 1
