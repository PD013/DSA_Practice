# %% [markdown]
# # ***Assignment_4_Doubly_Linked_List***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **SIRS FINAL ANSWER learning**

# %%
""" Doubly Linked List """
class Node:
    def __init__(self,prev=None,item=None,next=None):
        self.prev=prev
        self.item=item
        self.next=next
class DLL:
    def __init__(self,start=None):
        self.start=start
    def is_empty(self):
        return self.start==None
    def insert_at_start(self,data):
        n=Node(None,data,self.start)
        if not self.is_empty():
            self.start.prev=n
        self.start=n
    def insert_at_last(self,data):
        temp=self.start
        if self.start!=None:
            while temp.next!=None:
                temp=temp.next
        n=Node(temp,data,None)
        if temp==None:
            self.start=n
        else:
            temp.next=n
    def search(self,data):
        temp=self.start
        while temp is not None:
            if temp.item==data:
                return temp
            temp=temp.next
        return None
    def insert_after(self,temp,data):
        if temp is not None:
            n=Node(temp,data,temp.next)
            if temp.next is not None:
                temp.next.prev=n
            temp.next=n
    def print_list(self):
        temp=self.start
        while temp is not None:
            print(temp.item,end=' ')
            temp=temp.next
    def delete_first(self):
        if self.start is not None: # To check if its empty
            self.start=self.start.next
            if self.start is not None:  # To check if any node is there after deletin 1st to update prev
                self.start.prev=None
    def delete_last(self):
        if self.start is None: #Not empty
            pass
        elif self.start.next is None: # If only One Node in the list
            self.start=None
        else:
            temp=self.start
            while temp.next is not None:
                temp=temp.next
            temp.prev.next=None
    def delete_item(self,data):
        if self.start is None: #if empty
            pass
        else:
            temp=self.start
            while temp is not None:
                if temp.item==data:
                    if temp.next is not None:
                        temp.next.prev=temp.prev
                    if temp.prev is not None:
                        temp.prev.next=temp.next
                    else:
                        self.start=temp.next
                    break
                temp=temp.next
    def __iter__(self):
        return DLLIterator(self.start)
class DLLIterator:
    def __init__(self,start):
        self.current=start
    def __iter__(self):
        return self
    def __next__(self):
        if not self.current:
            raise StopIteration
        data = self.current.item
        self.current=self.current.next
        return data

mylist=DLL()
mylist.insert_at_start(10)
mylist.insert_at_last(20)
mylist.insert_after(mylist.search(10),15)
for x in mylist:
    print(x,end=' ')
print()
# Out:
# 10 15 20

# %% [markdown]
# ### **1. Define a class Node to describe a node of a doubly linked list.**

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        self.prev = None

# %% [markdown]
# ### **2. Define a class DLL to implement Doubly Linked List with __init__() method to create and initialise start reference variable.**

# %%
class DLL:
    def __init__(self):
        self.start = None

# %% [markdown]
# ### **3. Define a method is_empty() to check if the linked list is empty in DLL class.**

# %%
class DLL:
    def __init__(self):
        self.start = None

    def is_empty(self):
        return self.start is None

# %% [markdown]
# ### **4. In class DLL, define a method insert_at_start() to insert an element at the starting of the list.**:

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        self.prev = None
class DLL:
    def __init__(self):
        self.start = None

    def is_empty(self):
        return self.start is None

    def insert_at_start(self,data):
        new_node = Node(data)
        if self.start is None:
            self.start = new_node
        else:
            temp = self.start
            self.start = new_node
            new_node.next = temp
            temp.prev = new_node

# %% [markdown]
# ### **5. In class DLL, define a method insert_at_last() to insert an element at the end of the list.**

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        self.prev = None
class DLL:
    def __init__(self):
        self.start = None

    def is_empty(self):
        return self.start is None

    def insert_at_start(self,data):
        new_node = Node(data)
        if self.start is None:
            self.start = new_node
        else:
            temp = self.start
            self.start = new_node
            new_node.next = temp
            temp.prev = new_node
    def insert_at_last(self,data):
        new_node = Node(data)

        #If list is empty
        if self.start is None:
           self.start = new_node
           return

        temp = self.start
        while temp.next is not None:
            temp = temp.next
        new_node.prev = temp
        temp.next = new_node

# %% [markdown]
# ### **6. In class DLL, define a method search() to find the node with specified element value.**

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        self.prev = None
class DLL:
    def __init__(self):
        self.start = None

    def is_empty(self):
        return self.start is None

    def insert_at_start(self,data):
        new_node = Node(data)
        if self.start is None:
            self.start = new_node
        else:
            temp = self.start
            self.start = new_node
            new_node.next = temp
            temp.prev = new_node
    def insert_at_last(self,data):
        new_node = Node(data)

        #If list is empty
        if self.start is None:
           self.start = new_node
           return

        temp = self.start
        while temp.next is not None:
            temp = temp.next
        new_node.prev = temp
        temp.next = new_node

    def search(self,data):
        if self.start is None:
            print('Sorry The List is Empty')
            return

        temp = self.start
        i = 0

        while temp is not None:
            if temp.data == data:
                print(f"The Data '{data}' is in the {i}th Node! Congratsss")
                break
            temp = temp.next
            i += 1
        print(f"Data '{data}' not found in the linked list.")

# %% [markdown]
# ### **7. In class DLL, define a method insert_after() to insert a new node after a given node of the list.**

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        self.prev = None
class DLL:
    def __init__(self):
        self.start = None

    def is_empty(self):
        return self.start is None

    def insert_at_start(self,data):
        new_node = Node(data)
        if self.start is None:
            self.start = new_node
        else:
            temp = self.start
            self.start = new_node
            new_node.next = temp
            temp.prev = new_node

    def insert_at_last(self,data):
        new_node = Node(data)

        #If list is empty
        if self.start is None:
           self.start = new_node
           return

        temp = self.start
        while temp.next is not None:
            temp = temp.next
        new_node.prev = temp
        temp.next = new_node

    def search(self,data):
        if self.start is None:
            print('Sorry The List is Empty')
            return

        temp = self.start
        i = 1

        while temp is not None:
            if temp.data == data:
                print(f"The Data '{data}' is in the {i}th Node! Congratsss")
                return
            temp = temp.next
            i += 1
        print(f"Data '{data}' not found in the linked list.")

    def insert_after(self,data,new_data):
        new_node = Node(new_data)
        # Check if list is empty or not
        if self.start is None:
            print("The Linked List is Empty")
            return
        temp = self.start
        while temp.next is not None:
            if data == temp.data:
                temp.next.prev = new_node
                new_node.next = temp.next
                temp.next = new_node
                new_node.prev = temp
                return
            temp = temp.next
        # This is if the insert after is at last node
        if temp.next is None and temp.data == data:
            temp.next = new_node
            new_node.prev = temp
        else:
          print(f"Data '{data}' not found in the linked list.")

    def display(self):
        if self.start is None:
            print("The Linked List is Empty")
            return
        temp = self.start
        while temp is not None:
            print(f"{temp.data} <-> ", end=" ")
            temp = temp.next
        print("None")

# Create a doubly linked list
dll = DLL()

# Insert nodes at the start

#Insert at start and End woorking smoothly
dll.insert_at_start(3)
dll.insert_at_start(2)
dll.insert_at_start(1)

dll.insert_at_last(4)
dll.insert_at_last(5)

# Print the state of the list after deletion
dll.display()


# Here Insert After  All 4 conditions working OP

dll.insert_after(2, 2.5) # Insert in between
dll.display()

dll.insert_after(1, 1.5) # Inserting after 1st position
dll.display()

dll.insert_after(0, 0.5) # raising no such data found error
dll.display()

dll.insert_after(5, 5.5) # inserting at the end of the list
dll.display()

dll.search(1)
dll.search(1.5)
dll.search(0)
dll.search(5.5)
# Out:
# 1 <->  2 <->  3 <->  4 <->  5 <->  None
# 1 <->  2 <->  2.5 <->  3 <->  4 <->  5 <->  None
# 1 <->  1.5 <->  2 <->  2.5 <->  3 <->  4 <->  5 <->  None
# Data '0' not found in the linked list.
# 1 <->  1.5 <->  2 <->  2.5 <->  3 <->  4 <->  5 <->  None
# 1 <->  1.5 <->  2 <->  2.5 <->  3 <->  4 <->  5 <->  5.5 <->  None
# The Data '1' is in the 1th Node! Congratsss
# The Data '1.5' is in the 2th Node! Congratsss
# Data '0' not found in the linked list.
# The Data '5.5' is in the 8th Node! Congratsss

# %% [markdown]
# ### **8. In class DLL, define a method to print all the elements of the list.**

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        self.prev = None
class DLL:
    def __init__(self):
        self.start = None

    def is_empty(self):
        return self.start is None

    def insert_at_start(self,data):
        new_node = Node(data)
        if self.start is None:
            self.start = new_node
        else:
            temp = self.start
            self.start = new_node
            new_node.next = temp
            temp.prev = new_node

    def insert_at_last(self,data):
        new_node = Node(data)

        #If list is empty
        if self.start is None:
           self.start = new_node
           return

        temp = self.start
        while temp.next is not None:
            temp = temp.next
        new_node.prev = temp
        temp.next = new_node

    def search(self,data):
        if self.start is None:
            print('Sorry The List is Empty')
            return

        temp = self.start
        i = 1

        while temp is not None:
            if temp.data == data:
                print(f"The Data '{data}' is in the {i}th Node! Congratsss")
                return
            temp = temp.next
            i += 1
        print(f"Data '{data}' not found in the linked list.")

    def insert_after(self,data,new_data):
        new_node = Node(new_data)
        # Check if list is empty or not
        if self.start is None:
            print("The Linked List is Empty")
            return
        temp = self.start
        while temp.next is not None:
            if data == temp.data:
                temp.next.prev = new_node
                new_node.next = temp.next
                temp.next = new_node
                new_node.prev = temp
                return
            temp = temp.next
        # This is if the insert after is at last node
        if temp.next is None and temp.data == data:
            temp.next = new_node
            new_node.prev = temp
        else:
          print(f"Data '{data}' not found in the linked list.")

    def display(self):
        if self.start is None:
            print("The Linked List is Empty")
            return
        temp = self.start
        while temp is not None:
            print(f"{temp.data} <-> ", end=" ")
            temp = temp.next
        print("None")

    def print_all(self):
        temp = self.start
        while temp is not None:
            print(temp.data,end = ',')
            temp = temp.next

dll = DLL()

dll.insert_at_start(3)
dll.insert_at_start(2)
dll.insert_at_start(1)

dll.print_all()
# Out:
# 1,2,3,

# %% [markdown]
# ### **10. In class DLL, define a method delete_first() to delete first element from the list.**

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        self.prev = None
class DLL:
    def __init__(self):
        self.start = None

    def is_empty(self):
        return self.start is None

    def insert_at_start(self,data):
        new_node = Node(data)
        if self.start is None:
            self.start = new_node
        else:
            temp = self.start
            self.start = new_node
            new_node.next = temp
            temp.prev = new_node

    def insert_at_last(self,data):
        new_node = Node(data)

        #If list is empty
        if self.start is None:
           self.start = new_node
           return

        temp = self.start
        while temp.next is not None:
            temp = temp.next
        new_node.prev = temp
        temp.next = new_node

    def search(self,data):
        if self.start is None:
            print('Sorry The List is Empty')
            return

        temp = self.start
        i = 1

        while temp is not None:
            if temp.data == data:
                print(f"The Data '{data}' is in the {i}th Node! Congratsss")
                return
            temp = temp.next
            i += 1
        print(f"Data '{data}' not found in the linked list.")

    def insert_after(self,data,new_data):
        new_node = Node(new_data)
        # Check if list is empty or not
        if self.start is None:
            print("The Linked List is Empty")
            return
        temp = self.start
        while temp.next is not None:
            if data == temp.data:
                temp.next.prev = new_node
                new_node.next = temp.next
                temp.next = new_node
                new_node.prev = temp
                return
            temp = temp.next
        # This is if the insert after is at last node
        if temp.next is None and temp.data == data:
            temp.next = new_node
            new_node.prev = temp
        else:
          print(f"Data '{data}' not found in the linked list.")

    def display(self):
        if self.start is None:
            print("The Linked List is Empty")
            return
        temp = self.start
        while temp is not None:
            print(f"{temp.data} <-> ", end=" ")
            temp = temp.next
        print("None")

    def print_all(self):
        temp = self.start
        while temp is not None:
            print(temp.data,end = ',')
            temp = temp.next
    def delete_first(self):
        if self.start is None:
            print("The list is Already Empty oopsi")
            return
        temp = self.start
        if temp.next is None:
            self.start = None
        else:
            temp.next.prev = None
            self.start = temp.next


dll = DLL()

dll.insert_at_start(3)
dll.insert_at_start(2)
dll.insert_at_start(1)
dll.display()


dll.delete_first()

dll.display()
# Out:
# 1 <->  2 <->  3 <->  None
# 2 <->  3 <->  None

# %% [markdown]
# ### **11. In class DLL, define a method delete_last() to delete last element from the list.**

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        self.prev = None
class DLL:
    def __init__(self):
        self.start = None

    def is_empty(self):
        return self.start is None

    def insert_at_start(self,data):
        new_node = Node(data)
        if self.start is None:
            self.start = new_node
        else:
            temp = self.start
            self.start = new_node
            new_node.next = temp
            temp.prev = new_node

    def insert_at_last(self,data):
        new_node = Node(data)

        #If list is empty
        if self.start is None:
           self.start = new_node
           return

        temp = self.start
        while temp.next is not None:
            temp = temp.next
        new_node.prev = temp
        temp.next = new_node

    def search(self,data):
        if self.start is None:
            print('Sorry The List is Empty')
            return

        temp = self.start
        i = 1

        while temp is not None:
            if temp.data == data:
                print(f"The Data '{data}' is in the {i}th Node! Congratsss")
                return
            temp = temp.next
            i += 1
        print(f"Data '{data}' not found in the linked list.")

    def insert_after(self,data,new_data):
        new_node = Node(new_data)
        # Check if list is empty or not
        if self.start is None:
            print("The Linked List is Empty")
            return
        temp = self.start
        while temp.next is not None:
            if data == temp.data:
                temp.next.prev = new_node
                new_node.next = temp.next
                temp.next = new_node
                new_node.prev = temp
                return
            temp = temp.next
        # This is if the insert after is at last node
        if temp.next is None and temp.data == data:
            temp.next = new_node
            new_node.prev = temp
        else:
          print(f"Data '{data}' not found in the linked list.")

    def display(self):
        if self.start is None:
            print("The Linked List is Empty")
            return
        temp = self.start
        while temp is not None:
            print(f"{temp.data} <-> ", end=" ")
            temp = temp.next
        print("None")

    def print_all(self):
        temp = self.start
        while temp is not None:
            print(temp.data,end = ',')
            temp = temp.next
    def delete_first(self):
        if self.start is None:
            print("The list is Already Empty oopsi")
            return
        temp = self.start
        if temp.next is None:
            self.start = None
        else:
            temp.next.prev = None
            self.start = temp.next

    def delete_last(self):

        # if the list is empty
        if self.start is None:
            print('fk off the list is empty bro :) ' )
            return

        temp = self.start
        #This means there is only one element in the list
        if temp.next is None:
            self.start = None

        else:
            while temp.next.next is not None:
                temp = temp.next
            temp.next = None
            # Hence we disconnected the last from the 2nd last position easily

# %% [markdown]
# ### **12. In class DLL, define a method delete_item() to delete specified element from the list.**

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        self.prev = None
class DLL:
    def __init__(self):
        self.start = None

    def is_empty(self):
        return self.start is None

    def insert_at_start(self,data):
        new_node = Node(data)
        if self.start is None:
            self.start = new_node
        else:
            temp = self.start
            self.start = new_node
            new_node.next = temp
            temp.prev = new_node

    def insert_at_last(self,data):
        new_node = Node(data)

        #If list is empty
        if self.start is None:
           self.start = new_node
           return

        temp = self.start
        while temp.next is not None:
            temp = temp.next
        new_node.prev = temp
        temp.next = new_node

    def search(self,data):
        if self.start is None:
            print('Sorry The List is Empty')
            return

        temp = self.start
        i = 1

        while temp is not None:
            if temp.data == data:
                print(f"The Data '{data}' is in the {i}th Node! Congratsss")
                return
            temp = temp.next
            i += 1
        print(f"Data '{data}' not found in the linked list.")

    def insert_after(self,data,new_data):
        new_node = Node(new_data)
        # Check if list is empty or not
        if self.start is None:
            print("The Linked List is Empty")
            return
        temp = self.start
        while temp.next is not None:
            if data == temp.data:
                temp.next.prev = new_node
                new_node.next = temp.next
                temp.next = new_node
                new_node.prev = temp
                return
            temp = temp.next
        # This is if the insert after is at last node
        if temp.next is None and temp.data == data:
            temp.next = new_node
            new_node.prev = temp
        else:
          print(f"Data '{data}' not found in the linked list.")

    def display(self):
        if self.start is None:
            print("The Linked List is Empty")
            return
        temp = self.start
        while temp is not None:
            print(f"{temp.data} <-> ", end=" ")
            temp = temp.next
        print("None")

    def print_all(self):
        temp = self.start
        while temp is not None:
            print(temp.data,end = ',')
            temp = temp.next

    def delete_first(self):
        if self.start is None:
            print("The list is Already Empty oopsi")
            return
        temp = self.start
        if temp.next is None:
            self.start = None
        else:
            temp.next.prev = None
            self.start = temp.next

    def delete_last(self):

        # if the list is empty
        if self.start is None:
            print('fk off the list is empty bro :) ' )
            return

        temp = self.start
        #This means there is only one element in the list
        if temp.next is None:
            self.start = None

        else:
            while temp.next.next is not None:
                temp = temp.next
            temp.next = None
            # Hence we disconnected the last from the 2nd last position easily

    def delete_item(self,data):

        # Here the Case is if there is No node in the DLL
        if self.start is None:
            print("ur game ends here no stop because no one is alive bro :) ")
            return

        temp = self.start

        # Here if the node to be deleted is the first One in the list
        if temp.data == data:
            if temp.next is None:
                self.start = None
            else:
                temp.next.prev = None
                self.start = temp.next
            return

        # Here if the Node to be deleted is in the midlle of 2 nodes
        while temp.next.next is not None:

            if temp.next.data == data:
                temp.next.next.prev = temp
                temp.next = temp.next.next
                return
            temp = temp.next

        # if the data is in the last Node
        if temp.next.data == data: #(Here due to above while loop the temp is already at the 2nd last position)
            temp.next = None #(So it makes it easy for us to check at the last location)
            return

        # If data not found in any node
        print(f"Node with data '{data}' not found in the list.")


dll = DLL()


dll.insert_at_start(2)
dll.insert_at_start(1)
dll.insert_at_start(4)
dll.insert_at_start(3)
dll.insert_at_last(5)
dll.insert_after(4,4.5)
dll.display()





# dll.delete_item(3) # Its the 1st Node
# dll.delete_item(1) # It the Middle Node
# dll.delete_item(2) # It the Middle Node
# dll.delete_item(5) # It the Last Node
# dll.delete_item(31) # It No Such Node

#Hence all the function of the Delete is working


dll.display()
# Out:
# 3 <->  4 <->  4.5 <->  1 <->  2 <->  5 <->  None
# 3 <->  4 <->  4.5 <->  1 <->  2 <->  5 <->  None

# %% [markdown]
# ### **9. In class DLL, implement iterator for DLL to access all the elements of the list in a sequence.**

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        self.prev = None
class DLL:
    def __init__(self):
        self.start = None

    def is_empty(self):
        return self.start is None

    def insert_at_start(self,data):
        new_node = Node(data)
        if self.start is None:
            self.start = new_node
        else:
            temp = self.start
            self.start = new_node
            new_node.next = temp
            temp.prev = new_node

    def insert_at_last(self,data):
        new_node = Node(data)

        #If list is empty
        if self.start is None:
           self.start = new_node
           return

        temp = self.start
        while temp.next is not None:
            temp = temp.next
        new_node.prev = temp
        temp.next = new_node

    def search(self,data):
        if self.start is None:
            print('Sorry The List is Empty')
            return

        temp = self.start
        i = 1

        while temp is not None:
            if temp.data == data:
                print(f"The Data '{data}' is in the {i}th Node! Congratsss")
                return
            temp = temp.next
            i += 1
        print(f"Data '{data}' not found in the linked list.")

    def insert_after(self,data,new_data):
        new_node = Node(new_data)
        # Check if list is empty or not
        if self.start is None:
            print("The Linked List is Empty")
            return
        temp = self.start
        while temp.next is not None:
            if data == temp.data:
                temp.next.prev = new_node
                new_node.next = temp.next
                temp.next = new_node
                new_node.prev = temp
                return
            temp = temp.next
        # This is if the insert after is at last node
        if temp.next is None and temp.data == data:
            temp.next = new_node
            new_node.prev = temp
        else:
          print(f"Data '{data}' not found in the linked list.")

    def display(self):
        if self.start is None:
            print("The Linked List is Empty")
            return
        temp = self.start
        while temp is not None:
            print(f"{temp.data} <-> ", end=" ")
            temp = temp.next
        print("None")

    def print_all(self):
        temp = self.start
        while temp is not None:
            print(temp.data,end = ',')
            temp = temp.next

    def delete_first(self):
        if self.start is None:
            print("The list is Already Empty oopsi")
            return
        temp = self.start
        if temp.next is None:
            self.start = None
        else:
            temp.next.prev = None
            self.start = temp.next

    def delete_last(self):

        # if the list is empty
        if self.start is None:
            print('fk off the list is empty bro :) ' )
            return

        temp = self.start
        #This means there is only one element in the list
        if temp.next is None:
            self.start = None

        else:
            while temp.next.next is not None:
                temp = temp.next
            temp.next = None
            # Hence we disconnected the last from the 2nd last position easily

    def delete_item(self,data):

        # Here the Case is if there is No node in the DLL
        if self.start is None:
            print("ur game ends here no stop because no one is alive bro :) ")
            return

        temp = self.start

        # Here if the node to be deleted is the first One in the list
        if temp.data == data:
            if temp.next is None:
                self.start = None
            else:
                temp.next.prev = None
                self.start = temp.next
            return

        # Here if the Node to be deleted is in the midlle of 2 nodes
        while temp.next.next is not None:

            if temp.next.data == data:
                temp.next.next.prev = temp
                temp.next = temp.next.next
                return
            temp = temp.next

        # if the data is in the last Node
        if temp.next.data == data: #(Here due to above while loop the temp is already at the 2nd last position)
            temp.next = None #(So it makes it easy for us to check at the last location)
            return

        # If data not found in any node
        print(f"Node with data '{data}' not found in the list.")

    def __iter__(self):
        current = self.start
        while current:
            yield current.data
            current = current.next

dll = DLL()
dll.insert_at_start(4)
dll.insert_at_start(3)
dll.insert_at_start(2)
dll.insert_at_start(1)
dll.insert_at_last(5)
dll.insert_after(4,4.5)
dll.display()

#here iterator working wonderfully wooow
for x in dll:
    print(x,end='  ')
# Out:
# 1 <->  2 <->  3 <->  4 <->  4.5 <->  5 <->  None
# 1  2  3  4  4.5  5

# %% [markdown]
# # **How For Loop Works:**
#
# 1. Let c_iter = c.__iter__ ( ), which defines iteration over a Cafe object //Here the object can be anything
#
# 2. Call c_iter.__next__( ) to get the next value in the iteration process
#
# 3. Repeat Step 2 until we get Stoplteration Error raissed

# %% [markdown]
# There are two ways to iterate 1st is using itter function inside a class while creating a itterator class differently

# %%
# If, however, your iterator logic becomes more complex, or
# if you need additional methods or state in your iterator, you might consider creating a separate iterator class
class SLL:
    #Here there can be many more functions (bla..blaaa)
    def __iter__(self):
        return SLLIterator(self.start) # here we take self.start and give it to SLLIterator

class SLLIterator:
    def __init__(self,start):
        self.current=start #Here it assigns the Self.start to self.current

    def __iter__(self):
        return self

    def __next__(self):
        if not self.current:
            raise StopIteration
        data=self.current.item
        self.current=self.current.next
        return data
#It looks something like this

# %% [markdown]
# The Other way is using generators and not creating itterator class explicitly

# %% [markdown]
# ### CHECKING IF EVERYTHING WORKS FINE

# %%
#Its used when itteration in simple cases where you just want to iterate over the elements of the list.
class SLL:
    def __init__(self):
        self.start = None

    def __iter__(self):
        current = self.start
        while current:
            yield current.data
            current = current.next

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        self.prev = None
class DLL:
    def __init__(self):
        self.start = None

    def is_empty(self):
        return self.start is None

    def insert_at_start(self,data):
        new_node = Node(data)
        if self.start is None:
            self.start = new_node
        else:
            temp = self.start
            self.start = new_node
            new_node.next = temp
            temp.prev = new_node

    def insert_at_last(self,data):
        new_node = Node(data)

        #If list is empty
        if self.start is None:
           self.start = new_node
           return

        temp = self.start
        while temp.next is not None:
            temp = temp.next
        new_node.prev = temp
        temp.next = new_node

    def search(self,data):
        if self.start is None:
            print('Sorry The List is Empty')
            return

        temp = self.start
        i = 1

        while temp is not None:
            if temp.data == data:
                print(f"The Data '{data}' is in the {i}th Node! Congratsss")
                return
            temp = temp.next
            i += 1
        print(f"Data '{data}' not found in the linked list.")

    def insert_after(self,data,new_data):
        new_node = Node(new_data)
        # Check if list is empty or not
        if self.start is None:
            print("The Linked List is Empty")
            return
        temp = self.start
        while temp.next is not None:
            if data == temp.data:
                temp.next.prev = new_node
                new_node.next = temp.next
                temp.next = new_node
                new_node.prev = temp
                return
            temp = temp.next
        # This is if the insert after is at last node
        if temp.next is None and temp.data == data:
            temp.next = new_node
            new_node.prev = temp
        else:
          print(f"Data '{data}' not found in the linked list.")

    def display(self):
        if self.start is None:
            print("The Linked List is Empty")
            return
        temp = self.start
        while temp is not None:
            print(f"{temp.data} <-> ", end=" ")
            temp = temp.next
        print("None")

    def print_all(self):
        temp = self.start
        while temp is not None:
            print(temp.data,end = ',')
            temp = temp.next

    def delete_first(self):
        if self.start is None:
            print("The list is Already Empty oopsi")
            return
        temp = self.start
        if temp.next is None:
            self.start = None
        else:
            temp.next.prev = None
            self.start = temp.next

    def delete_last(self):

        # if the list is empty
        if self.start is None:
            print('fk off the list is empty bro :) ' )
            return

        temp = self.start
        #This means there is only one element in the list
        if temp.next is None:
            self.start = None

        else:
            while temp.next.next is not None:
                temp = temp.next
            temp.next = None
            # Hence we disconnected the last from the 2nd last position easily

    def delete_item(self,data):

        # Here the Case is if there is No node in the DLL
        if self.start is None:
            print("ur game ends here no stop because no one is alive bro :) ")
            return

        temp = self.start

        # Here if the node to be deleted is the first One in the list
        if temp.data == data:
            if temp.next is None:
                self.start = None
            else:
                temp.next.prev = None
                self.start = temp.next
            return

        # Here if the Node to be deleted is in the midlle of 2 nodes
        while temp.next.next is not None:

            if temp.next.data == data:
                temp.next.next.prev = temp
                temp.next = temp.next.next
                return
            temp = temp.next

        # if the data is in the last Node
        if temp.next.data == data: #(Here due to above while loop the temp is already at the 2nd last position)
            temp.next = None #(So it makes it easy for us to check at the last location)
            return

        # If data not found in any node
        print(f"Node with data '{data}' not found in the list.")

    def __iter__(self):
        current = self.start
        while current:
            yield current.data
            current = current.next



   # It Prints details of PREV , DATA , Next of Every NODE in the list

    def print_details(self):
        if self.start is None:
            print("The Linked List is Empty")
            return
        temp = self.start
        while temp is not None:
            print(f"Prev: {temp.prev.data if temp.prev else None} "
                  f"Data: {temp.data} "
                  f"Next: {temp.next.data if temp.next else None}")
            temp = temp.next
        print("None")

    # Other methods...

dll = DLL()
dll.insert_at_start(4)
dll.insert_at_start(3)
dll.insert_at_start(2)
dll.insert_at_start(1)
dll.insert_at_last(5)
dll.insert_after(4, 4.5)

dll.display()
print("\nDetails of each node:")
dll.print_details()
# Out:
# 1 <->  2 <->  3 <->  4 <->  4.5 <->  5 <->  None
#
# Details of each node:
# Prev: None Data: 1 Next: 2
# Prev: 1 Data: 2 Next: 3
# Prev: 2 Data: 3 Next: 4
# Prev: 3 Data: 4 Next: 4.5
# Prev: 4 Data: 4.5 Next: 5
# Prev: 4.5 Data: 5 Next: None
# None

# %% [markdown]
# ## **THIS IS THE FINAL WITH COMMENTS AND ALL THE TESTS**

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None

class DLL:
    def __init__(self):
        self.start = None

    def is_empty(self):
        return self.start is None

    def insert_at_start(self, data):
        new_node = Node(data)
        if self.start is None:
            self.start = new_node
        else:
            temp = self.start
            self.start = new_node
            new_node.next = temp
            temp.prev = new_node

    def insert_at_last(self, data):
        new_node = Node(data)

        # If list is empty
        if self.start is None:
            self.start = new_node
            return

        temp = self.start
        while temp.next is not None:
            temp = temp.next
        new_node.prev = temp
        temp.next = new_node

    def search(self, data):
        if self.start is None:
            print('Sorry, the list is empty')
            return

        temp = self.start
        i = 1

        while temp is not None:
            if temp.data == data:
                print(f"The data '{data}' is in the {i}th Node! Congrats")
                return
            temp = temp.next
            i += 1
        print(f"Data '{data}' not found in the linked list.")

    def insert_after(self, data, new_data):
        new_node = Node(new_data)
        # Check if the list is empty or not
        if self.start is None:
            print("The Linked List is empty")
            return
        temp = self.start
        while temp.next is not None:
            if data == temp.data:
                temp.next.prev = new_node
                new_node.next = temp.next
                temp.next = new_node
                new_node.prev = temp
                return
            temp = temp.next
        # This is if the insert after is at the last node
        if temp.next is None and temp.data == data:
            temp.next = new_node
            new_node.prev = temp
        else:
            print(f"Data '{data}' not found in the linked list.")

    def display(self):
        if self.start is None:
            print("The Linked List is empty")
            return
        temp = self.start
        while temp is not None:
            print(f"{temp.data} <-> ", end=" ")
            temp = temp.next
        print("None")

    def delete_first(self):
        if self.start is None:
            print("The list is already empty")
            return
        temp = self.start
        if temp.next is None:
            self.start = None
        else:
            temp.next.prev = None
            self.start = temp.next

    def delete_last(self):
        # If the list is empty
        if self.start is None:
            print('The list is empty')
            return

        temp = self.start
        # This means there is only one element in the list
        if temp.next is None:
            self.start = None
        else:
            while temp.next.next is not None:
                temp = temp.next
            temp.next = None

    def delete_item(self, data):
        # Here the case is if there is no node in the DLL
        if self.start is None:
            print("The list is empty")
            return

        temp = self.start

        # Here if the node to be deleted is the first one in the list
        if temp.data == data:
            if temp.next is None:
                self.start = None
            else:
                temp.next.prev = None
                self.start = temp.next
            return

        # Here if the Node to be deleted is in the middle of 2 nodes
        while temp.next.next is not None:

            if temp.next.data == data:
                temp.next.next.prev = temp
                temp.next = temp.next.next
                return
            temp = temp.next

        # If the data is in the last node
        if temp.next.data == data:
            temp.next = None  # So it makes it easy for us to check at the last location
            return

        # If data not found in any node
        print(f"Node with data '{data}' not found in the list.")

    def __iter__(self):
        current = self.start
        while current:
            yield current.data
            current = current.next

# Create an object to test the DLL class
test_dll = DLL()

# Test insert_at_start
test_dll.insert_at_start(4)
test_dll.insert_at_start(3)
test_dll.insert_at_start(2)
test_dll.insert_at_start(1)

# Test insert_at_last
test_dll.insert_at_last(5)

# Test insert_after
test_dll.insert_after(4, 4.5)

# Display the linked list
print("Linked List:")
test_dll.display()

# Test iterator
print("\nUsing Iterator:")
for x in test_dll:
    print(x, end=' ')

# Test delete_first
test_dll.delete_first()
print("\nAfter deleting first node:")
test_dll.display()

# Test delete_last
test_dll.delete_last()
print("After deleting last node:")
test_dll.display()

# Test delete_item
test_dll.delete_item(3)
print("After deleting node with data 3:")
test_dll.display()
# Out:
# Linked List:
# 1 <->  2 <->  3 <->  4 <->  4.5 <->  5 <->  None
#
# Using Iterator:
# 1 2 3 4 4.5 5
# After deleting first node:
# 2 <->  3 <->  4 <->  4.5 <->  5 <->  None
# After deleting last node:
# 2 <->  3 <->  4 <->  4.5 <->  None
# After deleting node with data 3:
# 2 <->  4 <->  4.5 <->  None
