# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Deque:
    def __init__(self):
        self.mylist = []
        # self.front = None  # NO need for this codee its waste
        # self.rear = None
        self.counter = 0
    def is_empty(self):
        return not self.mylist

    def insert_front(self,data):
        self.mylist.append(data)
        # if not is_empty(): # No need of this
        #     self.front = data
        # else:
        #     self.front = data
        #     self.rear = data

    def insert_rear(self,data):
        self.mylist.insert(0, data)
        # if not is_empty(): # No need of this
        #     self.rear = data
        # else:
        #     self.front = data
        #     self.rear = data

    def delete_front(self):
        if not self.is_empty():
            self.mylist.pop()
        else:
            raise IndexError("The list is empty")

    def delete_rear(self):
        if not self.is_empty():
            self.mylist.pop(0)
        else:
            raise IndexError("The list is empty")

    def get_front(self):
        if not self.is_empty():
            return self.mylist[-1]
        else:
            return None

    def get_rear(self):
        if not self.is_empty():
            return self.mylist[0]
        else:
            return None

    def size(self):
        return len(self.mylist)

q2 = Deque()

print(f"Initial size: {q2.size()}\n")

    # Inserting elements
print("Inserting elements:")
q2.insert_front(1)
print(f"Inserted front: 1, Current front: {q2.get_front()}, Current rear: {q2.get_rear()}, Size: {q2.size()}")
q2.insert_rear(2)
print(f"Inserted rear: 2, Current front: {q2.get_front()}, Current rear: {q2.get_rear()}, Size: {q2.size()}")
q2.insert_rear(3)
print(f"Inserted rear: 3, Current front: {q2.get_front()}, Current rear: {q2.get_rear()}, Size: {q2.size()}\n")

# Deleting elements
print("Deleting elements:")
q2.delete_front()
print(f"Deleted front, Current front: {q2.get_front()}, Current rear: {q2.get_rear()}, Size: {q2.size()}")
q2.delete_rear()
print(f"Deleted rear, Current front: {q2.get_front()}, Current rear: {q2.get_rear()}, Size: {q2.size()}\n")

# Inserting more elements
print("Inserting more elements:")
q2.insert_front(4)
print(f"Inserted front: 4, Current front: {q2.get_front()}, Current rear: {q2.get_rear()}, Size: {q2.size()}")
q2.insert_rear(5)
print(f"Inserted rear: 5, Current front: {q2.get_front()}, Current rear: {q2.get_rear()}, Size: {q2.size()}\n")

# Final state
print("Final state:")
print(f"Current front: {q2.get_front()}, Current rear: {q2.get_rear()}, Size: {q2.size()}")
# Out:
# Initial size: 0
#
# Inserting elements:
# Inserted front: 1, Current front: 1, Current rear: 1, Size: 1
# Inserted rear: 2, Current front: 1, Current rear: 2, Size: 2
# Inserted rear: 3, Current front: 1, Current rear: 3, Size: 3
#
# Deleting elements:
# Deleted front, Current front: 2, Current rear: 3, Size: 2
# Deleted rear, Current front: 2, Current rear: 2, Size: 1
#
# Inserting more elements:
# Inserted front: 4, Current front: 4, Current rear: 2, Size: 2
# Inserted rear: 5, Current front: 4, Current rear: 5, Size: 3
#
# Final state:
# Current front: 4, Current rear: 5, Size: 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)
