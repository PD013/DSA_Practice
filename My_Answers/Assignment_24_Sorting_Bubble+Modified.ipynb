# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class sorting:
    def bubble(self,lst):
        n = len(lst)


list1 = [2,1,5,4,3,6,8,7,6,9]

# %% [markdown]
# ![image.png](data:image/png;base64,...)
