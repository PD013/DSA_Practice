# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Here !wget and %load are magic commands in Jupyter notebooks. (Cannot work at other places)
# Use !wget to download the script from GitHub (Here I imported Sirs Code and Not Mine (Mine in ipynb))
# !wget https://github.com/PD013/DSA_Practice/raw/main/MySirG_Answers/Assign3_ANSWER_SIR.py

# Use %load to load the content into the cell
# %load Assign3_ANSWER_SIR.py

# here we are downloading and creating a file in same folder to use in this script
# Out:
# --2023-12-20 16:37:14--  https://github.com/PD013/DSA_Practice/raw/main/MySirG_Answers/Assign3_ANSWER_SIR.py
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/PD013/DSA_Practice/main/MySirG_Answers/Assign3_ANSWER_SIR.py [following]
# --2023-12-20 16:37:14--  https://raw.githubusercontent.com/PD013/DSA_Practice/main/MySirG_Answers/Assign3_ANSWER_SIR.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2728 (2.7K) [text/plain]
# Saving to: ‘Assign3_ANSWER_SIR.py.1’
#
# Assign3_ANSWER_SIR. 100%[===================>]   2.66K  --.-KB/s    in 0s
#
# 2023-12-20 16:37:14 (34.5 MB/s) - ‘Assign3_ANSWER_SIR.py.1’ saved [2728/2728]

# %%
# Only this command is required in local Env if the files are in same folder(Nothing else required)
from Assign3_ANSWER_SIR import *

# %%
class Stack:
    def __init__(self):
        self.mylist=SLL()
        self.item_count=0
    def is_empty(self):
        return self.mylist.is_empty()
    def push(self,data):
        self.mylist.insert_at_start(data)
        self.item_count+=1
    def pop(self):
        if not self.is_empty():
            self.mylist.delete_first()
            self.item_count-=1
    def peek(self):
        if not self.is_empty():
            return self.mylist.start.item
    def size(self):
        return self.item_count

s=Stack()
s.push(10)
s.push(20)
s.push(30)
print("Top element is",s.peek())
s.pop()
print("Top element is",s.peek())
print()
# Out:
# Top element is 30
# Top element is 20

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# I have noot written because too much time taken to import (No worries I understood the Code)
